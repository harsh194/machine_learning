# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh194/machine_learning/blob/main/maha_trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
new_directory = "/content/drive/MyDrive/Harsh/Machine Learning/Mahalanobis/"
os.chdir(new_directory)

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Harsh/Machine Learning/Mahalanobis'

# %%
# !pip install efficientnet_pytorch

# %%
from torchvision import datasets
import argparse
import numpy as np
import os
import pickle
from tqdm import tqdm
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import mahalanobis
import matplotlib.pyplot as plt

import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
from efficientnet_pytorch import EfficientNet

import os
import tarfile
from PIL import Image
from tqdm import tqdm
import urllib.request

import torch
from torch.utils.data import Dataset
from torchvision import transforms as T

# %matplotlib inline

# %%
# image = Image.open("000.png")

# transform = T.Compose([
#     T.Resize(256, Image.ANTIALIAS),
#     T.CenterCrop(224),
#     T.ToTensor(),
#     T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ])

# transformed_image = transform(image)

# transformed_image_np = transformed_image.numpy()
# plt.imshow(transformed_image_np.transpose(1, 2, 0))

# %%
transform_mask = T.Compose([T.Resize(256, Image.NEAREST),
                                         T.CenterCrop(224),
                                         T.ToTensor()])
image = Image.open("000.png")
masked_image = transform_mask(image)

masked_image_np = masked_image.numpy()
plt.imshow(masked_image_np.transpose(1, 2, 0))
