# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh194/machine_learning/blob/main/NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.externals._packaging.version import InvalidVersion
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons, make_circles, make_classification
# %matplotlib inline

# %%
# X, Y = make_moons(n_samples = 2000, noise = 0.15, random_state = 1)
#X, Y = make_circles(n_samples = 2000, noise = 0.1, random_state = 1, factor = 0.5)
#X, Y = make_classification(n_samples = 2000, n_features=2, n_redundant=0, random_state= 1)

# %%
def load_dataset(dataset):
    if dataset == 'moons':
        X, Y = make_moons(n_samples = 2000, noise = 0.15, random_state = 1)
    elif dataset == 'circles':
        X, Y = make_circles(n_samples = 2000, noise = 0.1, random_state = 1, factor = 0.5)
    elif dataset == 'classification':
        X, Y = make_classification(n_samples = 2000, n_features=2, n_redundant=0, random_state= 1)

    return X,Y

# %%
dataset = 'classification'
X,Y = load_dataset(dataset)

# %%
print(X.shape, Y.shape)
# Out:
# (2000, 2) (2000,)

# %%
plt.scatter(X[:,0], X[:,1], c = Y)

# %%
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(10, activation = 'relu', input_shape = (2,)))
model.add(Dense(5, activation = 'relu'))
model.add((Dense(1, activation = 'sigmoid')))

model.compile(loss = 'binary_crossentropy', metrics = 'accuracy')
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 10)                30
#
#  dense_13 (Dense)            (None, 5)                 55
#
#  dense_14 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 91 (364.00 Byte)
# Trainable params: 91 (364.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X, Y, batch_size = 64, epochs = 50, validation_split= 0.1)
# Out:
# Epoch 1/50
# 29/29 [==============================] - 1s 13ms/step - loss: 0.7568 - accuracy: 0.5000 - val_loss: 0.6872 - val_accuracy: 0.5200
# Epoch 2/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6499 - accuracy: 0.5167 - val_loss: 0.5963 - val_accuracy: 0.5600
# Epoch 3/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.5691 - accuracy: 0.5939 - val_loss: 0.5199 - val_accuracy: 0.6600
# Epoch 4/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.5046 - accuracy: 0.7494 - val_loss: 0.4634 - val_accuracy: 0.8550
# Epoch 5/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.4526 - accuracy: 0.8872 - val_loss: 0.4098 - val_accuracy: 0.9450
# Epoch 6/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.4049 - accuracy: 0.9361 - val_loss: 0.3640 - val_accuracy: 0.9500
# Epoch 7/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3655 - accuracy: 0.9417 - val_loss: 0.3277 - val_accuracy: 0.9500
# Epoch 8/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.3317 - accuracy: 0.9450 - val_loss: 0.2959 - val_accuracy: 0.9600
# Epoch 9/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2993 - accuracy: 0.9472 - val_loss: 0.2627 - val_accuracy: 0.9650
# Epoch 10/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2684 - accuracy: 0.9489 - val_loss: 0.2347 - val_accuracy: 0.9650
# Epoch 11/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2432 - accuracy: 0.9483 - val_loss: 0.2117 - val_accuracy: 0.9600
# Epoch 12/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2232 - accuracy: 0.9461 - val_loss: 0.1946 - val_accuracy: 0.9600
# Epoch 13/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2072 - accuracy: 0.9450 - val_loss: 0.1804 - val_accuracy: 0.9600
# Epoch 14/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1951 - accuracy: 0.9422 - val_loss: 0.1696 - val_accuracy: 0.9600
# Epoch 15/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1861 - accuracy: 0.9422 - val_loss: 0.1637 - val_accuracy: 0.9650
# Epoch 16/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1800 - accuracy: 0.9422 - val_loss: 0.1579 - val_accuracy: 0.9650
# Epoch 17/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1754 - accuracy: 0.9417 - val_loss: 0.1535 - val_accuracy: 0.9650
# Epoch 18/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1719 - accuracy: 0.9433 - val_loss: 0.1510 - val_accuracy: 0.9650
# Epoch 19/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1692 - accuracy: 0.9428 - val_loss: 0.1498 - val_accuracy: 0.9650
# Epoch 20/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1672 - accuracy: 0.9433 - val_loss: 0.1475 - val_accuracy: 0.9650
# Epoch 21/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1655 - accuracy: 0.9428 - val_loss: 0.1455 - val_accuracy: 0.9650
# Epoch 22/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1639 - accuracy: 0.9428 - val_loss: 0.1448 - val_accuracy: 0.9650
# Epoch 23/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.9439 - val_loss: 0.1436 - val_accuracy: 0.9650
# Epoch 24/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1614 - accuracy: 0.9433 - val_loss: 0.1429 - val_accuracy: 0.9700
# Epoch 25/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1607 - accuracy: 0.9444 - val_loss: 0.1413 - val_accuracy: 0.9700
# Epoch 26/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1598 - accuracy: 0.9444 - val_loss: 0.1405 - val_accuracy: 0.9700
# Epoch 27/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1590 - accuracy: 0.9467 - val_loss: 0.1405 - val_accuracy: 0.9700
# Epoch 28/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1582 - accuracy: 0.9456 - val_loss: 0.1406 - val_accuracy: 0.9700
# Epoch 29/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1575 - accuracy: 0.9461 - val_loss: 0.1403 - val_accuracy: 0.9700
# Epoch 30/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1570 - accuracy: 0.9461 - val_loss: 0.1388 - val_accuracy: 0.9700
# Epoch 31/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1563 - accuracy: 0.9472 - val_loss: 0.1381 - val_accuracy: 0.9700
# Epoch 32/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1558 - accuracy: 0.9472 - val_loss: 0.1370 - val_accuracy: 0.9700
# Epoch 33/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1553 - accuracy: 0.9472 - val_loss: 0.1376 - val_accuracy: 0.9700
# Epoch 34/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1548 - accuracy: 0.9472 - val_loss: 0.1372 - val_accuracy: 0.9700
# Epoch 35/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1544 - accuracy: 0.9472 - val_loss: 0.1375 - val_accuracy: 0.9700
# Epoch 36/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1541 - accuracy: 0.9478 - val_loss: 0.1370 - val_accuracy: 0.9700
# Epoch 37/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1535 - accuracy: 0.9483 - val_loss: 0.1362 - val_accuracy: 0.9700
# Epoch 38/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1533 - accuracy: 0.9483 - val_loss: 0.1359 - val_accuracy: 0.9700
# Epoch 39/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1528 - accuracy: 0.9478 - val_loss: 0.1354 - val_accuracy: 0.9700
# Epoch 40/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1524 - accuracy: 0.9472 - val_loss: 0.1356 - val_accuracy: 0.9700
# Epoch 41/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1519 - accuracy: 0.9483 - val_loss: 0.1344 - val_accuracy: 0.9700
# Epoch 42/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1518 - accuracy: 0.9478 - val_loss: 0.1343 - val_accuracy: 0.9700
# Epoch 43/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1515 - accuracy: 0.9483 - val_loss: 0.1344 - val_accuracy: 0.9700
# Epoch 44/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1512 - accuracy: 0.9478 - val_loss: 0.1347 - val_accuracy: 0.9700
# Epoch 45/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 0.9478 - val_loss: 0.1348 - val_accuracy: 0.9700
# Epoch 46/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1506 - accuracy: 0.9489 - val_loss: 0.1347 - val_accuracy: 0.9700
# Epoch 47/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1502 - accuracy: 0.9483 - val_loss: 0.1340 - val_accuracy: 0.9700
# Epoch 48/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1501 - accuracy: 0.9478 - val_loss: 0.1332 - val_accuracy: 0.9700
# Epoch 49/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1499 - accuracy: 0.9483 - val_loss: 0.1328 - val_accuracy: 0.9700
# Epoch 50/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1497 - accuracy: 0.9494 - val_loss: 0.1324 - val_accuracy: 0.9700
